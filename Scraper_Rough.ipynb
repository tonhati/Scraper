# %% [markdown]
# ## GitHub Topics Scrapper

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
topics_url = 'https://github.com/topics'

# %%
response = requests.get(topics_url)

# %%
page_contents = response.text

# %%
doc = BeautifulSoup(page_contents, 'html.parser')

# %% [markdown]
# ## Scraping Titles

# %%
selection_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'

topic_title_tag = doc.find_all('p', {'class': selection_class } )

# %%
len(topic_title_tag)
# Out:
# 30

# %%
topic_title_tag[:5]
# Out:
# [<p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amp</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>]

# %% [markdown]
# ## Scraping Descriptions

# %%
selection_class2 = 'f5 color-text-secondary mb-0 mt-1'

topic_description_tag = doc.find_all('p', {'class': selection_class2})

# %%
topic_description_tag[:5]
# Out:
# [<p class="f5 color-text-secondary mb-0 mt-1">
#                3D modeling is the process of virtually developing the surface and structure of a 3D object.
#              </p>,
#  <p class="f5 color-text-secondary mb-0 mt-1">
#                Ajax is a technique for creating interactive web applications.
#              </p>,
#  <p class="f5 color-text-secondary mb-0 mt-1">
#                Algorithms are self-contained sequences that carry out a variety of tasks.
#              </p>,
#  <p class="f5 color-text-secondary mb-0 mt-1">
#                Amp is a non-blocking concurrency framework for PHP.
#              </p>,
#  <p class="f5 color-text-secondary mb-0 mt-1">
#                Android is an operating system built by Google designed for mobile devices.
#              </p>]

# %% [markdown]
# ## Scraping URLs

# %%
selection_class3 = 'd-flex no-underline'

topic_url_tag =  doc.find_all('a', {'class': selection_class3})

#To get Url:
#topic0_url = 'https://github.com' + topic_url[0]['href']
#print(topic0_url)

# %% [markdown]
# ## Appending Tags to Lists

# %%
topic_title = []

for tag in topic_title_tag:
    topic_title.append(tag.text)
    
print(topic_title[0])
# Out:
# 3D

# %%
topic_description = []

for tag in topic_description_tag:
    topic_description.append(tag.text.strip())
    
print(topic_description[0])
# Out:
# 3D modeling is the process of virtually developing the surface and structure of a 3D object.

# %%
topic_urls = []
base_url = 'https://github.com'

for tag in topic_url_tag:
    topic_urls.append(base_url+tag['href'])
    

print(topic_urls[0])
# Out:
# https://github.com/topics/3d

# %% [markdown]
# ## Transform Lists into Dictionary, then into DataFrames.

# %%
topics_dict = {'title': topic_title, 'description': topic_description, 'URL': topic_urls}

# %%
topics_df = pd.DataFrame(topics_dict)

topics_df
# Out:
#                      title                                        description  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency framework fo...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Google Chrome Extensions are add-ons that allo...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                  URL
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                    https://github.com/topics/atom
# 11                 https://github.com/topics/awesome
# 12                     https://github.com/topics/aws
# 13                   https://github.com/topics/azure
# 14                   https://github.com/topics/babel
# 15                    https://github.com/topics/bash
# 16                 https://github.com/topics/bitcoin
# 17               https://github.com/topics/bootstrap
# 18                     https://github.com/topics/bot
# 19                       https://github.com/topics/c
# 20                  https://github.com/topics/chrome
# 21        https://github.com/topics/chrome-extension
# 22                     https://github.com/topics/cli
# 23                 https://github.com/topics/clojure
# 24            https://github.com/topics/code-quality
# 25             https://github.com/topics/code-review
# 26                https://github.com/topics/compiler
# 27  https://github.com/topics/continuous-integration
# 28                https://github.com/topics/covid-19
# 29                     https://github.com/topics/cpp

# %% [markdown]
# ## Creating CSV file with the extracted information

# %%
topics_df.to_csv('topics.csv', index = None)

# %% [markdown]
# ## Getting information out of Topic Page

# %%
topic_page_url = topic_urls[0]

# %%
response = requests.get(topic_page_url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.text)
# Out:
# 619849

# %%
topic_doc = BeautifulSoup(response.text, 'html.parser')

# %%
h1_selection_class = 'f3 color-text-secondary text-normal lh-condensed'

repo_tags = topic_doc.find_all('h3', {'class': h1_selection_class})

# %%
len(repo_tags)
# Out:
# 30

# %%
repo_tags[0]
# Out:
# <h3 class="f3 color-text-secondary text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":97088,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="4bdbc49d3c05ae7f70b531fbce709a384200b0768554e0172950286a8db30940" data-view-component="true" href="/mrdoob">
#             mrdoob
# </a>          /
#           <a class="text-bold" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":576201,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="517d3d5cb9d89752156923904a4238816bc9b51ab7772f3e3644ce897d8dd4e5" data-view-component="true" href="/mrdoob/three.js">
#             three.js
# </a> </h3>

# %%
a_tags = repo_tags[0].find_all('a')

# %%
a_tags[0].text.strip()
# Out:
# 'mrdoob'

# %%
a_tags[1].text.strip()
# Out:
# 'three.js'

# %%
repo_url = base_url + a_tags[1]['href']
print(repo_url)
# Out:
# https://github.com/mrdoob/three.js

# %%
star_tags = topic_doc.find_all('a', {'class': 'social-count float-none'})

# %%
star_tags[0].text.strip()
# Out:
# '73.6k'

# %% [markdown]
# ### Defining Function to Transform from 73.5k format to 73500

# %%
def parse_star_count(stars_str):
    stars_str = stars_str.strip()
    if stars_str[-1] == 'k':
        return int(float(stars_str[:-1])*1000)
    return int(stars_str)

# %% [markdown]
# ### Defining Function to get Information from the Repository

# %%
def get_repo_info(h1_tag, star_tag):
    #Returns all required information about a repository
    a_tags = h1_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, stars, repo_url

# %%
get_repo_info(repo_tags[0], star_tags[0])
# Out:
# ('mrdoob', 'three.js', 73600, 'https://github.com/mrdoob/three.js')

# %% [markdown]
# ### Append the Information to Dictionary

# %%
topic_repos_dict = {'username': [],'repo_name': [],'stars': [],'repo_url': []}


for i in range(len(repo_tags)):
    repo_info = get_repo_info(repo_tags[i], star_tags[i])
    topic_repos_dict['username'].append(repo_info[0])
    topic_repos_dict['repo_name'].append(repo_info[1])
    topic_repos_dict['stars'].append(repo_info[2])
    topic_repos_dict['repo_url'].append(repo_info[3])

# %%
topic_repos_dict
# Out:
# {'username': ['mrdoob',
#   'libgdx',
#   'pmndrs',
#   'BabylonJS',
#   'aframevr',
#   'ssloy',
#   'lettier',
#   'FreeCAD',
#   'metafizzy',
#   'CesiumGS',
#   'timzhang642',
#   'a1studmuffin',
#   'isl-org',
#   'spritejs',
#   'tensorspace-team',
#   'jagenjo',
#   'YadiraF',
#   'AaronJackson',
#   'domlysz',
#   'openscad',
#   'ssloy',
#   'mosra',
#   'google',
#   'blender',
#   'gfxfundamentals',
#   'cleardusk',
#   'jasonlong',
#   'rg3dengine',
#   'antvis',
#   'cnr-isti-vclab'],
#  'repo_name': ['three.js',
#   'libgdx',
#   'react-three-fiber',
#   'Babylon.js',
#   'aframe',
#   'tinyrenderer',
#   '3d-game-shaders-for-beginners',
#   'FreeCAD',
#   'zdog',
#   'cesium',
#   '3D-Machine-Learning',
#   'SpaceshipGenerator',
#   'Open3D',
#   'spritejs',
#   'tensorspace',
#   'webglstudio.js',
#   'PRNet',
#   'vrn',
#   'BlenderGIS',
#   'openscad',
#   'tinyraytracer',
#   'magnum',
#   'model-viewer',
#   'blender',
#   'webgl-fundamentals',
#   '3DDFA',
#   'isometric-contributions',
#   'rg3d',
#   'L7',
#   'meshlab'],
#  'stars': [73600,
#   18800,
#   14700,
#   14700,
#   13000,
#   11100,
#   10900,
#   9700,
#   8600,
#   7400,
#   6900,
#   6900,
#   5000,
#   4600,
#   4500,
#   4400,
#   4400,
#   4400,
#   4200,
#   4200,
#   3800,
#   3600,
#   3300,
#   3200,
#   3100,
#   3100,
#   3000,
#   2600,
#   2400,
#   2300],
#  'repo_url': ['https://github.com/mrdoob/three.js',
#   'https://github.com/libgdx/libgdx',
#   'https://github.com/pmndrs/react-three-fiber',
#   'https://github.com/BabylonJS/Babylon.js',
#   'https://github.com/aframevr/aframe',
#   'https://github.com/ssloy/tinyrenderer',
#   'https://github.com/lettier/3d-game-shaders-for-beginners',
#   'https://github.com/FreeCAD/FreeCAD',
#   'https://github.com/metafizzy/zdog',
#   'https://github.com/CesiumGS/cesium',
#   'https://github.com/timzhang642/3D-Machine-Learning',
#   'https://github.com/a1studmuffin/SpaceshipGenerator',
#   'https://github.com/isl-org/Open3D',
#   'https://github.com/spritejs/spritejs',
#   'https://github.com/tensorspace-team/tensorspace',
#   'https://github.com/jagenjo/webglstudio.js',
#   'https://github.com/YadiraF/PRNet',
#   'https://github.com/AaronJackson/vrn',
#   'https://github.com/domlysz/BlenderGIS',
#   'https://github.com/openscad/openscad',
#   'https://github.com/ssloy/tinyraytracer',
#   'https://github.com/mosra/magnum',
#   'https://github.com/google/model-viewer',
#   'https://github.com/blender/blender',
#   'https://github.com/gfxfundamentals/webgl-fundamentals',
#   'https://github.com/cleardusk/3DDFA',
#   'https://github.com/jasonlong/isometric-contributions',
#   'https://github.com/rg3dengine/rg3d',
#   'https://github.com/antvis/L7',
#   'https://github.com/cnr-isti-vclab/meshlab']}

# %% [markdown]
# ### Transform into DataFrame

# %%
topic_repos_df = pd.DataFrame(topic_repos_dict)

# %%
topic_repos_df

# These are the top 30 repositories for the topid 3D... Now I want do the same for all scraped topics
# Out:
#             username                      repo_name  stars  \
# 0             mrdoob                       three.js  73600
# 1             libgdx                         libgdx  18800
# 2             pmndrs              react-three-fiber  14700
# 3          BabylonJS                     Babylon.js  14700
# 4           aframevr                         aframe  13000
# 5              ssloy                   tinyrenderer  11100
# 6            lettier  3d-game-shaders-for-beginners  10900
# 7            FreeCAD                        FreeCAD   9700
# 8          metafizzy                           zdog   8600
# 9           CesiumGS                         cesium   7400
# 10       timzhang642            3D-Machine-Learning   6900
# 11      a1studmuffin             SpaceshipGenerator   6900
# 12           isl-org                         Open3D   5000
# 13          spritejs                       spritejs   4600
# 14  tensorspace-team                    tensorspace   4500
# 15           jagenjo                 webglstudio.js   4400
# 16           YadiraF                          PRNet   4400
# 17      AaronJackson                            vrn   4400
# 18           domlysz                     BlenderGIS   4200
# 19          openscad                       openscad   4200
# 20             ssloy                  tinyraytracer   3800
# 21             mosra                         magnum   3600
# 22            google                   model-viewer   3300
# 23           blender                        blender   3200
# 24   gfxfundamentals             webgl-fundamentals   3100
# 25         cleardusk                          3DDFA   3100
# 26         jasonlong        isometric-contributions   3000
# 27        rg3dengine                           rg3d   2600
# 28            antvis                             L7   2400
# 29    cnr-isti-vclab                        meshlab   2300
#
#                                              repo_url
# 0                  https://github.com/mrdoob/three.js
# 1                    https://github.com/libgdx/libgdx
# 2         https://github.com/pmndrs/react-three-fiber
# 3             https://github.com/BabylonJS/Babylon.js
# 4                  https://github.com/aframevr/aframe
# 5               https://github.com/ssloy/tinyrenderer
# 6   https://github.com/lettier/3d-game-shaders-for...
# 7                  https://github.com/FreeCAD/FreeCAD
# 8                   https://github.com/metafizzy/zdog
# 9                  https://github.com/CesiumGS/cesium
# 10  https://github.com/timzhang642/3D-Machine-Lear...
# 11  https://github.com/a1studmuffin/SpaceshipGener...
# 12                  https://github.com/isl-org/Open3D
# 13               https://github.com/spritejs/spritejs
# 14    https://github.com/tensorspace-team/tensorspace
# 15          https://github.com/jagenjo/webglstudio.js
# 16                   https://github.com/YadiraF/PRNet
# 17                https://github.com/AaronJackson/vrn
# 18              https://github.com/domlysz/BlenderGIS
# 19               https://github.com/openscad/openscad
# 20             https://github.com/ssloy/tinyraytracer
# 21                    https://github.com/mosra/magnum
# 22             https://github.com/google/model-viewer
# 23                 https://github.com/blender/blender
# 24  https://github.com/gfxfundamentals/webgl-funda...
# 25                 https://github.com/cleardusk/3DDFA
# 26  https://github.com/jasonlong/isometric-contrib...
# 27                 https://github.com/rg3dengine/rg3d
# 28                       https://github.com/antvis/L7
# 29          https://github.com/cnr-isti-vclab/meshlab

# %%
#
# CLEANING UP
#



# parse_star_count:
# Takes str input in the format 76.5K and returns int 765000
def parse_star_count(stars_str):
    stars_str = stars_str.strip()
    if stars_str[-1] == 'k':
        return int(float(stars_str[:-1])*1000)
    return int(stars_str)

# get_topic_page:
# Given a Topic Url it's going to try to download the page. 
# Give me an error if it was not succesfull. 
# Parse Using BeautifulSoup
def get_topic_page(topic_url):
    # Download the Page
    response = requests.get(topic_url)
    
    # Check Download Response
    if response.status_code != 200:
        raise Exception(f'Falied to load page{topic_url}')
    
    #Parse Using BeautifulSoup
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    
    return topic_doc

# get_repo_info:
# Given h1_tag and star_tag returns Username, Repository Name, Repository Stars, and URL.
def get_repo_info(h1_tag, star_tag):
    #Returns all required information about a repository
    a_tags = h1_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, stars, repo_url

# get_topic_repos:
# Gets the h3 tags that we need
# Creates Dictionary
# Inputs repository info into dictionary
# Returns dataframe
def get_topic_repos(topic_doc):  
    # Get the h3 tags containing repo title, repo URL and username
    h3_selection_class = 'f3 color-text-secondary text-normal lh-condensed'
    repo_tags = topic_doc.find_all('h3', {'class': h3_selection_class})
    
    # Get star tags
    star_tags = topic_doc.find_all('a', {'class': 'social-count float-none'})
    
    # Get repository info
    topic_repos_dict = {'username': [],'repo_name': [],'stars': [],'repo_url': []}
    for i in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[i], star_tags[i])
        topic_repos_dict['username'].append(repo_info[0])
        topic_repos_dict['repo_name'].append(repo_info[1])
        topic_repos_dict['stars'].append(repo_info[2])
        topic_repos_dict['repo_url'].append(repo_info[3])
        
    #Transforming into dataframe
    return pd.DataFrame(topic_repos_dict)

# %% [markdown]
# ### Testing

# %%
url4 = topic_urls[4]

# %%
topic4_doc = get_topic_page(url4)

# %%
topic4_repos = get_topic_repos(topic4_doc)

# %%
topic4_repos
# Out:
#                  username                      repo_name   stars  \
# 0                 flutter                        flutter  128000
# 1               justjavac   free-programming-books-zh_CN   82200
# 2              Genymobile                         scrcpy   53200
# 3        Hack-with-Github                Awesome-Hacking   45500
# 4                  google          material-design-icons   43600
# 5                wasabeef             awesome-android-ui   41100
# 6                  square                         okhttp   40600
# 7                 android           architecture-samples   39300
# 8                  square                       retrofit   38500
# 9                  Solido                awesome-flutter   37000
# 10                PhilJay                 MPAndroidChart   33800
# 11               fastlane                       fastlane   32800
# 12            shadowsocks            shadowsocks-android   31800
# 13                 airbnb                 lottie-android   31600
# 14               bumptech                          glide   31600
# 15                 Trinea           android-open-project   30700
# 16                 Blankj                AndroidUtilCode   29700
# 17                   xitu                     gold-miner   29400
# 18               bilibili                      ijkplayer   29300
# 19                  zxing                          zxing   28200
# 20               codepath                 android_guides   27500
# 21                 skylot                           jadx   26900
# 22                 square                     leakcanary   26500
# 23              laurent22                         joplin   24700
# 24                alibaba                       fastjson   23700
# 25               scwang90             SmartRefreshLayout   22900
# 26                CymChad  BaseRecyclerViewAdapterHelper   22200
# 27  react-native-elements          react-native-elements   21100
# 28                 google                        iosched   20700
# 29           NativeScript                   NativeScript   20400
#
#                                              repo_url
# 0                  https://github.com/flutter/flutter
# 1   https://github.com/justjavac/free-programming-...
# 2                https://github.com/Genymobile/scrcpy
# 3   https://github.com/Hack-with-Github/Awesome-Ha...
# 4     https://github.com/google/material-design-icons
# 5      https://github.com/wasabeef/awesome-android-ui
# 6                    https://github.com/square/okhttp
# 7     https://github.com/android/architecture-samples
# 8                  https://github.com/square/retrofit
# 9           https://github.com/Solido/awesome-flutter
# 10          https://github.com/PhilJay/MPAndroidChart
# 11               https://github.com/fastlane/fastlane
# 12  https://github.com/shadowsocks/shadowsocks-and...
# 13           https://github.com/airbnb/lottie-android
# 14                  https://github.com/bumptech/glide
# 15     https://github.com/Trinea/android-open-project
# 16          https://github.com/Blankj/AndroidUtilCode
# 17                 https://github.com/xitu/gold-miner
# 18              https://github.com/bilibili/ijkplayer
# 19                     https://github.com/zxing/zxing
# 20         https://github.com/codepath/android_guides
# 21                     https://github.com/skylot/jadx
# 22               https://github.com/square/leakcanary
# 23                https://github.com/laurent22/joplin
# 24                https://github.com/alibaba/fastjson
# 25     https://github.com/scwang90/SmartRefreshLayout
# 26  https://github.com/CymChad/BaseRecyclerViewAda...
# 27  https://github.com/react-native-elements/react...
# 28                  https://github.com/google/iosched
# 29       https://github.com/NativeScript/NativeScript

# %%
# In one Line:

get_topic_repos(get_topic_page(topic_urls[5]))
# Out:
#         username                             repo_name  stars  \
# 0      justjavac          free-programming-books-zh_CN  82200
# 1        angular                               angular  75800
# 2    storybookjs                             storybook  64099
# 3     ionic-team                       ionic-framework  45100
# 4    leonardomso                        33-js-concepts  43100
# 5       prettier                              prettier  40300
# 6        SheetJS                               sheetjs  27000
# 7        angular                           angular-cli  24800
# 8        angular                            components  21700
# 9   NativeScript                          NativeScript  20400
# 10        Eugeny                                 tabby  18900
# 11      jhipster                    generator-jhipster  18700
# 12  handsontable                          handsontable  15600
# 13       teambit                                   bit  13900
# 14   sweetalert2                           sweetalert2  13300
# 15  goldbergyoni     javascript-testing-best-practices  12900
# 16     linnovate                                  mean  12100
# 17        coreui  coreui-free-bootstrap-admin-template  10900
# 18   codesandbox                    codesandbox-client  10800
# 19     PatrickJS                       angular-starter  10400
# 20    Chocobozzz                              PeerTube   9600
# 21       angular                            protractor   8800
# 22       OnsenUI                               OnsenUI   8400
# 23          nrwl                                    nx   8100
# 24     text-mask                             text-mask   8000
# 25     PatrickJS                       awesome-angular   8000
# 26  ng-bootstrap                          ng-bootstrap   7800
# 27      NG-ZORRO                         ng-zorro-antd   7700
# 28       ag-grid                               ag-grid   7500
# 29       rematch                               rematch   7400
#
#                                              repo_url
# 0   https://github.com/justjavac/free-programming-...
# 1                  https://github.com/angular/angular
# 2            https://github.com/storybookjs/storybook
# 3       https://github.com/ionic-team/ionic-framework
# 4       https://github.com/leonardomso/33-js-concepts
# 5                https://github.com/prettier/prettier
# 6                  https://github.com/SheetJS/sheetjs
# 7              https://github.com/angular/angular-cli
# 8               https://github.com/angular/components
# 9        https://github.com/NativeScript/NativeScript
# 10                    https://github.com/Eugeny/tabby
# 11     https://github.com/jhipster/generator-jhipster
# 12       https://github.com/handsontable/handsontable
# 13                     https://github.com/teambit/bit
# 14         https://github.com/sweetalert2/sweetalert2
# 15  https://github.com/goldbergyoni/javascript-tes...
# 16                  https://github.com/linnovate/mean
# 17  https://github.com/coreui/coreui-free-bootstra...
# 18  https://github.com/codesandbox/codesandbox-client
# 19       https://github.com/PatrickJS/angular-starter
# 20             https://github.com/Chocobozzz/PeerTube
# 21              https://github.com/angular/protractor
# 22                 https://github.com/OnsenUI/OnsenUI
# 23                         https://github.com/nrwl/nx
# 24             https://github.com/text-mask/text-mask
# 25       https://github.com/PatrickJS/awesome-angular
# 26       https://github.com/ng-bootstrap/ng-bootstrap
# 27          https://github.com/NG-ZORRO/ng-zorro-antd
# 28                 https://github.com/ag-grid/ag-grid
# 29                 https://github.com/rematch/rematch

# %%
topic_urls[5]
# Out:
# 'https://github.com/topics/angular'

# %% [markdown]
# ### Saving to CSV

# %%
get_topic_repos(get_topic_page(topic_urls[5])).to_csv('angular.csv', index = None)

# %% [markdown]
# ## Writing function to :
#
# ### 1- Get the list of topics from the topics page
# ### 2- Get the list of top repos from the individual topic pages
# ### 3- For each topic, create a CSV of the top repos for the topic

# %%
def get_topic_titles(doc):
    # Selecting Topic Title 
    selection_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'
    topic_title_tag = doc.find_all('p', {'class': selection_class } )
    # Appending Topic Titles to List
    topic_title = []
    for tag in topic_title_tag:
        topic_title.append(tag.text)
    return topic_title

def get_topic_descriptions(doc):
    # Selecting Topic Description
    selection_class2 = 'f5 color-text-secondary mb-0 mt-1'
    topic_description_tag = doc.find_all('p', {'class': selection_class2})
    # Appending Topic Descriptions to List
    topic_description = []
    for tag in topic_description_tag:
        topic_description.append(tag.text.strip()) 
    return topic_description
    
def get_topic_urls(doc):
    #  Selecting Topic URL
    selection_class3 = 'd-flex no-underline'
    topic_url_tag =  doc.find_all('a', {'class': selection_class3})
    # Appending topic Url to List
    topic_urls = []
    base_url = 'https://github.com'
    for tag in topic_url_tag:
        topic_urls.append(base_url+tag['href'])
    return topic_urls
    

def scrape_topics():
    topics_url = 'https://github.com/topics'
    response = requests.get(topics_url)
    if response.status_code != 200:
        raise Exception(f'Failed to load page{topic_url}')
    # Transforming Lists into Dictionary
    topics_dict = {'title': get_topic_titles(doc), 
                   'description': get_topic_descriptions(doc), 
                   'URL': get_topic_urls(doc)}
    # Transforiming Dictionary into DF
    topics_df = pd.DataFrame(topics_dict)
    return pd.DataFrame(topics_dict)

# %%
scrape_topics()
# Out:
#                      title                                        description  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency framework fo...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Google Chrome Extensions are add-ons that allo...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                  URL
# 0                       https://github.com/topics/3d
# 1                     https://github.com/topics/ajax
# 2                https://github.com/topics/algorithm
# 3                    https://github.com/topics/amphp
# 4                  https://github.com/topics/android
# 5                  https://github.com/topics/angular
# 6                  https://github.com/topics/ansible
# 7                      https://github.com/topics/api
# 8                  https://github.com/topics/arduino
# 9                   https://github.com/topics/aspnet
# 10                    https://github.com/topics/atom
# 11                 https://github.com/topics/awesome
# 12                     https://github.com/topics/aws
# 13                   https://github.com/topics/azure
# 14                   https://github.com/topics/babel
# 15                    https://github.com/topics/bash
# 16                 https://github.com/topics/bitcoin
# 17               https://github.com/topics/bootstrap
# 18                     https://github.com/topics/bot
# 19                       https://github.com/topics/c
# 20                  https://github.com/topics/chrome
# 21        https://github.com/topics/chrome-extension
# 22                     https://github.com/topics/cli
# 23                 https://github.com/topics/clojure
# 24            https://github.com/topics/code-quality
# 25             https://github.com/topics/code-review
# 26                https://github.com/topics/compiler
# 27  https://github.com/topics/continuous-integration
# 28                https://github.com/topics/covid-19
# 29                     https://github.com/topics/cpp

# %%
# Tool to Write Topic URL, Topic Page, and Repositories to CSV file

#def scrape_topic(topic_url, topic_name):
#    # From topic Url we get Topic Page, From topic Page we get the repositories
#    topic_df = get_topic_repos(get_topic_page(topic_url))
#    # We then write all that in a CSV File
#    topic_df.to_csv(topic_name + '.csv', index=None)

# %%
# Now I'm adding a check on the scrape_topic function. it will not download csv files that already exist

import os

def scrape_topic(topic_url, topic_name):
    fname = topic_name + '.csv'
    if os.path.exists(fname):
        print(f'The file {fname} already exists. Skipping...')
        return
    # From topic Url we get Topic Page, From topic Page we get the repositories
    topic_df = get_topic_repos(get_topic_page(topic_url))
    # We then write all that in a CSV File
    topic_df.to_csv(fname, index=None)

# %%
def scrape_topics_repos():
    print('Scraping list of from GitHub')
    # we use the function scrape_topics to return the DataFrame with all our topics, their descriptions, and URL
    topics_df = scrape_topics()
    for index, row in topics_df.iterrows():
        title = row['title']
        URL = row['URL']
        print(f'Scraping top repositories for {title} from {URL}')
        scrape_topic(URL, f'data/{title}.csv')

# %%
scrape_topics_repos()
# Out:
# Scraping list of from GitHub
# Scraping top repositories for 3D from https://github.com/topics/3d
# Scraping top repositories for Ajax from https://github.com/topics/ajax
# Scraping top repositories for Algorithm from https://github.com/topics/algorithm
# Scraping top repositories for Amp from https://github.com/topics/amphp
# The file data/Amp.csv.csv already exists. Skipping...
# Scraping top repositories for Android from https://github.com/topics/android
# The file data/Android.csv.csv already exists. Skipping...
# Scraping top repositories for Angular from https://github.com/topics/angular
# The file data/Angular.csv.csv already exists. Skipping...
# Scraping top repositories for Ansible from https://github.com/topics/ansible
# The file data/Ansible.csv.csv already exists. Skipping...
# Scraping top repositories for API from https://github.com/topics/api
# The file data/API.csv.csv already exists. Skipping...
# Scraping top repositories for Arduino from https://github.com/topics/arduino
# The file data/Arduino.csv.csv already exists. Skipping...
# Scraping top repositories for ASP.NET from https://github.com/topics/aspnet
# The file data/ASP.NET.csv.csv already exists. Skipping...
# Scraping top repositories for Atom from https://github.com/topics/atom
# The file data/Atom.csv.csv already exists. Skipping...
# Scraping top repositories for Awesome Lists from https://github.com/topics/awesome
# The file data/Awesome Lists.csv.csv already exists. Skipping...
# Scraping top repositories for Amazon Web Services from https://github.com/topics/aws
# The file data/Amazon Web Services.csv.csv already exists. Skipping...
# Scraping top repositories for Azure from https://github.com/topics/azure
# The file data/Azure.csv.csv already exists. Skipping...
# Scraping top repositories for Babel from https://github.com/topics/babel
# The file data/Babel.csv.csv already exists. Skipping...
# Scraping top repositories for Bash from https://github.com/topics/bash
# The file data/Bash.csv.csv already exists. Skipping...
# Scraping top repositories for Bitcoin from https://github.com/topics/bitcoin
# The file data/Bitcoin.csv.csv already exists. Skipping...
# Scraping top repositories for Bootstrap from https://github.com/topics/bootstrap
# The file data/Bootstrap.csv.csv already exists. Skipping...
# Scraping top repositories for Bot from https://github.com/topics/bot
# The file data/Bot.csv.csv already exists. Skipping...
# Scraping top repositories for C from https://github.com/topics/c
# The file data/C.csv.csv already exists. Skipping...
# Scraping top repositories for Chrome from https://github.com/topics/chrome
# The file data/Chrome.csv.csv already exists. Skipping...
# Scraping top repositories for Chrome extension from https://github.com/topics/chrome-extension
# The file data/Chrome extension.csv.csv already exists. Skipping...
# Scraping top repositories for Command line interface from https://github.com/topics/cli
# The file data/Command line interface.csv.csv already exists. Skipping...
# Scraping top repositories for Clojure from https://github.com/topics/clojure
# The file data/Clojure.csv.csv already exists. Skipping...
# Scraping top repositories for Code quality from https://github.com/topics/code-quality
# The file data/Code quality.csv.csv already exists. Skipping...
# Scraping top repositories for Code review from https://github.com/topics/code-review
# The file data/Code review.csv.csv already exists. Skipping...
# Scraping top repositories for Compiler from https://github.com/topics/compiler
# The file data/Compiler.csv.csv already exists. Skipping...
# Scraping top repositories for Continuous integration from https://github.com/topics/continuous-integration
# The file data/Continuous integration.csv.csv already exists. Skipping...
# Scraping top repositories for COVID-19 from https://github.com/topics/covid-19
# The file data/COVID-19.csv.csv already exists. Skipping...
# Scraping top repositories for C++ from https://github.com/topics/cpp
# The file data/C++.csv.csv already exists. Skipping...
